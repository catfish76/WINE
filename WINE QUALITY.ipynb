# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import missingno as msno
import os

# %%
wine=pd.read_csv('C:/Users/HP/Downloads/wine.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine.shape
# Out:
# (1143, 13)

# %%
wine.size
# Out:
# 14859

# %%
len(wine)
# Out:
# 1143

# %%
print('number of columns',wine.shape[1])
# Out:
# number of columns 13

# %%
print('number of rows',wine.shape[0])
# Out:
# number of rows 1143

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine=wine.drop(labels=['Id'],axis=1)

# %%
wine.duplicated().any()
# Out:
# True

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.hist()
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# ### fixed acidity to quality

# %%
plt.bar(wine['quality'],wine['fixed acidity'])
plt.xlabel('fixed acidity')
plt.ylabel('quality')
plt.show()

# %%
#quality of wine is high at fixed acidity of 5 to 7

# %% [markdown]
# ### volatile acidity to quality

# %%
plt.bar(wine['quality'],wine['volatile acidity'])
plt.xlabel('volatile acidity')
plt.ylabel('quality')
plt.show()

# %%
#volatile acidity reduces as quslity of wine increases

# %% [markdown]
# ### citric acid vs quality

# %%
plt.bar(wine['quality'],wine['citric acid'])
plt.ylabel('quality')
plt.xlabel('citric acid')
plt.show()

# %%
#quality is good at citric acid between 4 and 5

# %% [markdown]
# ### residual sugar and quality

# %%
plt.bar(wine['quality'],wine['residual sugar'])
plt.ylabel('quality')
plt.xlabel('residual sugar')
plt.show()

# %%
#residual sugar between 5 and 6  quality is highest

# %% [markdown]
# ### chlorides and quality

# %%
plt.bar(wine['quality'],wine['chlorides'])
plt.ylabel('quality')
plt.xlabel('chlorides')
plt.show()

# %%
#chlorides between 4 and 5  quality is highest

# %% [markdown]
# ## alcohol and quality

# %%
plt.bar(wine['quality'],wine['alcohol'])
plt.ylabel('quality')
plt.xlabel('alcohol')
plt.show()

# %%
#alcohol from 4 to 8 increased quality of wine

# %% [markdown]
# ## correlation matrix

# %%
plt.figure(figsize=(10,5))
sns.heatmap(wine.corr(),vmin=-1,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## BINARIAZATION OF THE TARGET COLUMN

# %%
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#we are going to map these 6 values into 2 to make it easy for the machine learning algorithm to predict

# %%
wine['quality']=[1 if x >= 7 else 0 for x in wine ['quality']]

# %%
wine['quality'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1133            6.7             0.320         0.44             2.4      0.061
# 1134            7.5             0.310         0.41             2.4      0.065
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
feature=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']

# %%
list(enumerate(feature))
# Out:
# [(0, 'fixed acidity'),
#  (1, 'volatile acidity'),
#  (2, 'citric acid'),
#  (3, 'residual sugar'),
#  (4, 'chlorides'),
#  (5, 'free sulfur dioxide'),
#  (6, 'total sulfur dioxide'),
#  (7, 'density'),
#  (8, 'pH'),
#  (9, 'sulphates'),
#  (10, 'alcohol'),
#  (11, 'quality')]

# %%
plt.figure(figsize=(50,100))
for i in enumerate(feature):
    plt.subplot(6,2,i[0]+1)
    sns.countplot(i[1],hue='quality',data=wine)
    plt.xticks(rotation=90)

# %%
#This means bad quality wine be represnted by 0 and good quality wine be represented by 1

# %% [markdown]
# ## NOT HANDLING IMBALANCE DATASET

# %%
wine['quality'].value_counts()
# Out:
# 0    984
# 1    159
# Name: quality, dtype: int64

# %%
wine['quality'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#or i can use

# %%
sns.countplot(wine['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# ### store feature matrix in X and response target in vector y

# %%
X= wine.drop('quality',axis=1)

# %%
y=wine['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: quality, Length: 1143, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.06639731 0.11084412 0.10474122 0.07092231 0.06086471 0.06443673
#  0.06826874 0.07232924 0.06987294 0.10952456 0.20179812]

# %%
feat_importances=pd.Series(model.feature_importances_,index=X.columns)
feat_importances.nlargest(11).plot(kind='barh')
plt.show()

# %% [markdown]
# ##    SPLIT THE DATASET

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
len(X_train)
# Out:
# 914

# %%
len(X_test)
# Out:
# 229

# %% [markdown]
# ## FEATURE SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)

# %%
X_test=sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 0.1426802 , -1.40273053,  1.5096933 , ..., -0.09314751,
#          0.56821234,  0.05661327],
#        [ 0.96843134, -1.17920341,  1.5096933 , ..., -1.07474038,
#          0.4477703 ,  0.89445566],
#        [ 0.3786091 , -1.23508519,  0.4833938 , ...,  0.56124774,
#          0.20688622,  1.26683005],
#        ...,
#        [-0.50612428, -1.01155806,  0.32944888, ...,  0.29948964,
#         -0.33510296,  1.35992365],
#        [-0.21121315,  0.21784112,  0.22681893, ..., -0.15858703,
#          0.20688622, -0.87432272],
#        [-0.44714205, -0.06156778,  0.6886537 , ..., -0.35490561,
#         -0.09421888,  1.26683005]])

# %% [markdown]
# ### PRINCIPAL COMPONENT ANALYSIS

# %% [markdown]
# #IS A DIMENTIONALITY REDUCTION METHOD,IT IS USED TO REDUCE THE DIMENTIONALITY OF A LARGE
# #DATASET BY TRANSFORMING A LARGE SET OF VARIABLES INTO A SMALLER ONE.BUT STILL CONTAINS MOST INFORMATIONS
# #IN THE LARGE SET HENCE QUALITY IS RETAINED.WHEN YOU GIVE AN INPUT OF VARIABLES TO PCA THE OUTPUT IS A COMPLETE
# #NEW SET OF FEATURES.
# #MEANS PCA WILL DETECT INFORMATIONS IN FOR EXAMPLE 10 COLUMNS AND GIVE YOU BACK OUTPUT IN 2 COLUMNS.
# #BUT THESE 2 COLUMNS IS GOOD ENOUGH TO REPRESENT THE 10 LARGER COLUMN

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.90)

# %%
X_train=pca.fit_transform(X_train)

# %%
X_test=pca.fit_transform(X_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.30274015, 0.16817669, 0.12847304, 0.11252967, 0.08521268,
#        0.06235558, 0.05305692])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9125447116229338

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.8951965065502183

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.6428571428571429

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.32142857142857145

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.4285714285714286

# %% [markdown]
# ## HANDLING IMBALANCE DATASET

# %% [markdown]
# ### SMOTH

# %% [markdown]
# #### SYNTHETIC MINORITY OVERSAMPLING TECHNIQUE

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res=SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# 0    984
# 1    984
# Name: quality, dtype: int64

# %%
y_res.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### WE HAVE TO PERFORM ALL PROCESSES UNDER SMOTH

# %% [markdown]
# ## SPLIT THE DATASET AFTER SMOTH

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %% [markdown]
# ## FEATURE SCALING AFTER SMOTH

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)

# %%
X_test=sc.fit_transform(X_test)

# %% [markdown]
# ## PRINCIPAL COMPONENT ANALYSIS AFTER SMOTH

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.90)

# %%
X_train=pca.fit_transform(X_train)

# %%
X_test=pca.fit_transform(X_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.29141318, 0.1811378 , 0.15116754, 0.10045527, 0.08706692,
#        0.05800513, 0.04788374])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9171295812105237

# %% [markdown]
# ## LOGISTIC REGRESION AFTER SMOTH

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.7385786802030457

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.7528735632183908

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.6858638743455497

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7178082191780822

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
classifier=ExtraTreesClassifier()

# %%
classifier.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
score=classifier.feature_importances_

# %%
print (score)
# Out:
# [0.07717893 0.10625178 0.10654969 0.07370341 0.06425691 0.06685021
#  0.07840624 0.0853152  0.07006685 0.10236127 0.16905953]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %% [markdown]
# ### SVC

# %%
from sklearn import svm

# %%
svm=svm.SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred2=svm.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.7157360406091371

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.6755555555555556

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.7958115183246073

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.7307692307692308

# %% [markdown]
# ## KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3=knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.8883248730964467

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.8209606986899564

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9842931937172775

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.8952380952380953

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4=dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.9213197969543148

# %%
precision_score(y_test,y_pred4)
# Out:
# 0.9040404040404041

# %%
recall_score(y_test,y_pred4)
# Out:
# 0.93717277486911

# %%
f1_score(y_test,y_pred4)
# Out:
# 0.9203084832904885

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.9619289340101523

# %%
precision_score(y_test,y_pred5)
# Out:
# 0.9444444444444444

# %%
recall_score(y_test,y_pred5)
# Out:
# 0.9790575916230366

# %%
f1_score(y_test,y_pred5)
# Out:
# 0.961439588688946

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6=gb.predict(X_test)

# %%
accuracy_score(y_test,y_pred6)
# Out:
# 0.9365482233502538

# %%
precision_score(y_test,y_pred6)
# Out:
# 0.9191919191919192

# %%
f1_score(y_test,y_pred6)
# Out:
# 0.93573264781491

# %%
recall_score(y_test,y_pred6)
# Out:
# 0.9528795811518325

# %% [markdown]
# ## SAVE THE MODEL

# %%
final_data1=pd.DataFrame({'Models':['log','svc','knn','dt','rf','gb'],
             'ACC':[accuracy_score(y_test,y_pred1)*100,
                    accuracy_score(y_test,y_pred2)*100,                           
                    accuracy_score(y_test,y_pred3)*100,                                
                    accuracy_score(y_test,y_pred4)*100,
                    accuracy_score(y_test,y_pred5)*100,
                    accuracy_score(y_test,y_pred6)*100]})

# %%
final_data1
# Out:
#   Models        ACC
# 0    log  73.857868
# 1    svc  71.573604
# 2    knn  88.832487
# 3     dt  92.131980
# 4     rf  96.192893
# 5     gb  93.654822

# %%
sns.barplot(final_data1['Models'],final_data1['ACC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %%
final_data2=pd.DataFrame({'Models':['log','svc','knn','dt','rf','gb'],
             'PRE':[precision_score(y_test,y_pred1)*100,
                    precision_score(y_test,y_pred2)*100,                           
                    precision_score(y_test,y_pred3)*100,                                
                    precision_score(y_test,y_pred4)*100,
                    precision_score(y_test,y_pred5)*100,
                    precision_score(y_test,y_pred6)*100]})

# %%
final_data2
# Out:
#   Models        PRE
# 0    log  75.287356
# 1    svc  67.555556
# 2    knn  82.096070
# 3     dt  90.404040
# 4     rf  94.444444
# 5     gb  91.919192

# %%
sns.barplot(final_data2['Models'],final_data2['PRE'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='PRE'>

# %%
final_data3=pd.DataFrame({'Models':['log','svc','knn','dt','rf','gb'],
             'REC':[recall_score(y_test,y_pred1)*100,
                    recall_score(y_test,y_pred2)*100,                           
                    recall_score(y_test,y_pred3)*100,                                
                    recall_score(y_test,y_pred4)*100,
                    recall_score(y_test,y_pred5)*100,
                    recall_score(y_test,y_pred6)*100]})

# %%
final_data3
# Out:
#   Models        REC
# 0    log  68.586387
# 1    svc  79.581152
# 2    knn  98.429319
# 3     dt  93.717277
# 4     rf  97.905759
# 5     gb  95.287958

# %%
sns.barplot(final_data3['Models'],final_data3['REC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='REC'>

# %%
final_data4=pd.DataFrame({'Models':['log','svc','knn','dt','rf','gb'],
             'F1':[f1_score(y_test,y_pred1)*100,
                    f1_score(y_test,y_pred2)*100,                           
                    f1_score(y_test,y_pred3)*100,                                
                    f1_score(y_test,y_pred4)*100,
                    f1_score(y_test,y_pred5)*100,
                    f1_score(y_test,y_pred6)*100]})

# %%
final_data4
# Out:
#   Models         F1
# 0    log  71.780822
# 1    svc  73.076923
# 2    knn  89.523810
# 3     dt  92.030848
# 4     rf  96.143959
# 5     gb  93.573265

# %%
sns.barplot(final_data4['Models'],final_data4['F1'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='F1'>

# %% [markdown]
# ### DATA SCIENCE DEVELOPER BUILD GUI APP FOR THIS PROJECT

# %% [markdown]
# ### SAVE THE MODEL

# %%
X= wine.drop('quality',axis=1)

# %%
y=wine['quality']

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res=SMOTE().fit_resample(X,y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X=sc.fit_transform(X_res)

# %%
X=pca.fit_transform(X)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(X,y_res)
# Out:
# GradientBoostingClassifier()

# %%
import joblib

# %%
joblib.dump(gb,'wine_quality_prediction')
# Out:
# ['wine_quality_prediction']

# %%
model = joblib.load('wine_quality_prediction')

# %% [markdown]
# ## LETS PERFORM PREDICTION USING THE MODEL CREATED

# %%
import pandas as pd

# %%
new_wine=pd.DataFrame({'fixed acidity':7.4, 'volatile acidity':0.70,'citric acid':0.0,'residual sugar':1.9,
       'chlorides':0.076,'free sulfur dioxide':11.0,'total sulfur dioxide':34.0,'density':0.9978,
       'pH':3.51,'sulphates':0.56,'alcohol':9.4,
      },index=[0])

# %%
new_wine
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4

# %%
test=pca.transform(sc.transform(new_wine))

# %%
p=model.predict(test)

# %%
p
# Out:
# array([0], dtype=int64)

# %%
if p[0]==0:
    print('Bad Quality Wine')
else:
    print('Good Quality Wine')
# Out:
# Bad Quality Wine

# %% [markdown]
# ## GUI

# %%
from tkinter import *
from sklearn.preprocessing import StandardScaler
import joblib

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    p9=float(e9.get()) 
    p10=float(e10.get())
    p11=float(e11.get())
    model = joblib.load('wine_quality_prediction')
    result=model.predict(pca.transform(sc.transform([[p1,p2,p3,p4,p5,p6,
                           p7,p8,p9,p10,p11]])))
    
    
    if result[0] == 0:
        Label(master, text="Bad Quality Wine").grid(row=31)
    else:
        Label(master, text="Good Quality Wine").grid(row=31)
        
master = Tk()
master.title("Wine Quality Prediction Using Machine Learning")

label = Label(master, text = "Wine Quality Prediction Using ML"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)

Label(master, text="fixed acidity").grid(row=1)
Label(master, text="volatile acidity").grid(row=2)
Label(master, text="citric acid").grid(row=3)
Label(master, text="residual sugar").grid(row=4)
Label(master, text="chlorides").grid(row=5)
Label(master, text="free sulfur dioxide").grid(row=6)
Label(master, text="total sulfur dioxide").grid(row=7)
Label(master, text="density").grid(row=8)
Label(master, text="pH").grid(row=9)
Label(master, text="sulphates").grid(row=10)
Label(master,text="alcohol").grid(row=11)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)
e10 = Entry(master)
e11 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10,column=1)
e11.grid(row=11,column=1)

Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()
